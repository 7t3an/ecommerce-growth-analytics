# %%
from src.db import run_sql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = run_sql("../sql/user_behavior_mart.sql")

# %%
df.describe()
# Out:
#         views_count     cart_adds  wishlist_adds  purchase_events  \
# count  10000.000000  10000.000000   10000.000000     10000.000000
# mean       5.601300      1.203500       0.794600         0.400600
# std        2.354505      1.095996       0.886842         0.634318
# min        0.000000      0.000000       0.000000         0.000000
# 25%        4.000000      0.000000       0.000000         0.000000
# 50%        5.000000      1.000000       1.000000         0.000000
# 75%        7.000000      2.000000       1.000000         1.000000
# max       16.000000      7.000000       5.000000         6.000000
#
#         active_days
# count  10000.000000
# mean       7.950800
# std        2.784269
# min        0.000000
# 25%        6.000000
# 50%        8.000000
# 75%       10.000000
# max       23.000000

# %%
df.head()
# Out:
#    user_id  views_count  cart_adds  wishlist_adds  purchase_events  \
# 0  U000001            4          1              0                0
# 1  U000002            5          1              1                0
# 2  U000003            9          1              1                0
# 3  U000004            3          1              0                1
# 4  U000005            5          0              0                0
#
#    active_days first_activity last_activity
# 0            5     2024-01-13    2025-09-22
# 1            7     2024-05-31    2025-10-16
# 2           11     2024-03-25    2025-02-23
# 3            5     2024-04-20    2025-11-03
# 4            5     2024-05-10    2025-07-13

# %%
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(8, 5))
sns.histplot(data=df, x="views_count", bins=30, kde=True, ax=ax)
ax.set_title("Distribution of Views per User")
ax.set_xlabel("Views Count")
ax.set_ylabel("Number of Users")
plt.tight_layout()
plt.show()
